# %%
with open('/content/Уэллс_-_Война_миров.txt', 'r', encoding='cp1251') as file:
    text = file.read()

# %%
words = [word.lower() for word in text.split()]

word_count = len(words)
line_count = text.count('\n')
char_count_with_spaces = len(text)
char_count_without_spaces = len(text.replace(' ', ''))

print(f'Всего слов: {word_count}')
print(f'Всего строк: {line_count}')
print(f'Всего символов (вкл. пробелы): {char_count_with_spaces}')
print(f'Всего символов (не вкл. пробелы): {char_count_without_spaces}')
# Out:
# Всего слов: 45354
# Всего строк: 2128
# Всего символов (вкл. пробелы): 298375
# Всего символов (не вкл. пробелы): 254657

# %%
import matplotlib.pyplot as plt

# %%
stop_w = ['и', 'или', 'но', 'а', 'для', 'чтобы', 'если', 'также', 'более', 'менее', '-','о', 'в', 'c', 'к', 'из', 'за', 'от', 'у']

word_freq = {}
for word in words:
    if word not in stop_w:
        if word not in word_freq:
            word_freq[word] = 1
        else:
            word_freq[word] += 1
      
top_words = sorted(word_freq.items(), key=lambda x: x[1], reverse=True)[:20]

words = [word[0] for word in top_words]
freqs = [word[1] for word in top_words]

plt.bar(words, freqs)
plt.title('20 наиболее употребляемых слов')
plt.xlabel('Слова')
plt.ylabel('Частота')
plt.xticks(rotation=90)
plt.show()
